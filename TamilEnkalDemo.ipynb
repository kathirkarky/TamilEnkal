# %%
# !pip install TamilEnkal

# %%
import TamilEnkal as te

# %%
te.TamilEn(123)
# Out:
# '௧௨௩'

# %%
te.ArabuEn('௧௨௩')
# Out:
# 123

# %%
te.TamilSutru(1245.678)
# Out:
# '௧௨௪௬'

# %%
te.ArabuSutru('௧.௧௨௪௬')
# Out:
# 1

# %%
te.Perumam(1,2)
# Out:
# '௨'

# %%
te.Sirumam(2,3)
# Out:
# '௨'

# %%
te.Koottal(1,2)
# Out:
# '௩'

# %%
te.Kazhithal(1,-1)
# Out:
# '௨'

# %%
te.Perukkal(1,4)
# Out:
# '௪'

# %%
te.Eevu(2,5)
# Out:
# '௦.௪'

# %%
te.Meedhi(3,4)
# Out:
# '௩'
